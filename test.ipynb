# %%
import numpy as np
import pandas as pd

# %%
x = np.random.rand(1,1000) #comment 1
y = np.random.rand(1,1000) #comment 2

# %%
df = pd.DataFrame(np.random.randint(0,5000,size=(5000, 2)), columns=list('AB'))
df.plot('A', 'B')
