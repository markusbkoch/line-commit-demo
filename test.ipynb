# %%
import numpy as np
import pandas as pd

# %%
x = np.random.rand(1,1000)
y = np.random.rand(1,1000)

# %%
df = pd.DataFrame(np.random.randint(0,10000,size=(10000, 2)), columns=list('AB'))
df.plot('A', 'B')
